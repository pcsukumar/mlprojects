# %% [markdown]
# ## Applying classification algorithm on the iris flower data set
# ----

# %% [markdown]
# #### Introduction

# %% [markdown]
# Machine learning is a subfield of artificial intelligence (AI) that focuses on the development of algorithms that can learn from data without being explicitly programmed. It is inspired by the way that humans learn, which is by observing the world around them and making inferences about how things work. Machine learning algorithms are able to learn from data by identifying patterns and relationships between the data points (Sandhu, 2018; IBM). Machine learning algorithms are typically trained on large amounts of data. The algorithm learns from the data by comparing patterns in the data to patterns that it has already seen. This process of learning allows the algorithm to make predictions about new data that it has never seen before. This powerful tool is being used to solve a wide variety of problems including; Predictive modeling, image recognition, natural language processing, spam filtering, fraud detection, medical diagnosis etc.

# %% [markdown]
# #### Supervised learning

# %% [markdown]
# Machine learning algorithms can be classified as supervised learning, unsupervised learning, and reinforcement learning. Among these, supervised and unsupervised learning are the main classes and the difference between these two classes is the existence of labels in the training data subset (Alpaydın, 2014).
# Supervised machine learning focuses on training algorithms to learn from labelled data. Labelled data is data that has been pre-classified or annotated with the desired output or outcome. In supervised machine learning, the algorithm is presented with a set of labelled training data and then learns to map input data to the corresponding output data. The algorithms attempt to predict and classify the predetermined attribute, and their accuracies and misclassification alongside other performance measures.
#
# In essence, supervised algorithms perform analytical tasks first using the training data and subsequently construct contingent functions for mapping new instance of the attribute. Data usually will be split randomly 70-30 or 80-20 into train and test datasets respectively in statistical modelling, in which training data utilized for building the model and its effectiveness will be checked on test data.  Supervised learning is arguably the most common usage of ML (Verdhan, 2022).
#
# The supervised learning algorithms are further classified into classification and regression algorithms. Regression is used when the aim is to predict the value of a continuous variable while classification is used when want to predict the value of a categorical variable. The output of a regression problem will be a continuous value (Berry et al. 2019). Logistic regression, Decision trees (classification trees), Random Forest classifier, SVM classifier etc. are examples of supervised learning algorithms.
#
# In contrast, unsupervised learning does not require predefined labels or categories for the data. Instead, the algorithm is tasked with discovering patterns and relationships within the data itself. This means that the algorithm does not have any specific target to aim for, but rather it must explore the data on its own to identify patterns and relationships. This allows for the identification of hidden insights and structures that may not be apparent from the data's raw form. One of the main goals of unsupervised learning is to cluster the data, meaning to group similar data points together. This can be useful for tasks such as customer segmentation, where the algorithm can identify distinct groups of customers based on their buying behaviour or preferences. Principal component analysis (PCA) and K-means clustering are main unsupervised learning algorithms (Verdhan, 2022).

# %% [markdown]
# #### Clasification algorithms

# %% [markdown]
# Classification is a type of supervised machine learning wherein the algorithm is trained to predict the appropriate category or label for a given set of input data. The process involves utilizing a training dataset to teach the model how to associate input features with specific output labels. Once the model is trained, it is tested on a separate dataset (test data) to assess its performance and ensure its ability to generalize to new, unseen data. This two-step process of training and evaluation is crucial for ensuring the model's reliability and effectiveness in making accurate predictions when applied to real-world scenarios.
#
# Classification algorithms can be categorized into two main types: parametric and nonparametric (Khadka, nd.). The distinction between these two types lies in their assumptions about the underlying data distribution. Parametric algorithms rely on pre-established notions about the distribution and patterns within the data, employing a set of predetermined parameters to forecast new data points based on these assumptions. These algorithms are generally have lower computational complexity and are computationally more efficient, making them suitable for large datasets. Examples include linear regression, logistic regression, and Gaussian Naive Bayes.
#
# Nonparametric algorithms operate without imposing rigid constraints on the data distribution or the underlying predictor function, granting them greater flexibility and adaptability to the intricacies of the data. This freedom comes at the cost of increased data requirements and computational demands. These algorithms can be computationally intensive, especially as the size of the dataset increases, due to their reliance on the entire dataset during predictionExamples include k-nearest neighbors (KNN), decision trees, and support vector machines.

# %% [markdown]
# #### k-Nearest Neighbors classification

# %% [markdown]
# k-Nearest Neighbors classification is one of the most popular ML techniques where the learning is based on the similarity of data points with each other. KNN is well-suited for classification tasks where the underlying patterns between features and the target class are intricate, but instances within a class share a high degree of similarity in terms of attribute values. KNN's strength lies in its ability to handle complex relationships between attributes and target classes while utilizing the inherent homogeneity within classes to make accurate classifications (Zhang 2016). This makes it a powerful tool for situations where the underlying patterns are difficult to discern but the class structure is relatively clear.
#
# The steps which are followed in k-nearest neighbor are as follows (Verdhan 2022)
#
# 1. The KNN algorithm is initiated with a raw, unclassified dataset containing new data points.
#
# 2. A suitable distance metric, such as Euclidean, Manhattan, or Minkowski, is chosen to quantify the similarity between data points. Gnerally KNN employs Euclidean distance which can be calculated with the following equation
# \begin{equation}
# d(x, y) = \sqrt{\sum_{i=1}^n (x_i - y_i)^2}
# \end{equation}
#
# where $x$ and $y$ are the two points to be compared, $n$ is the number of features in the dataset, and $x_i$ and $y_i$ are the values of the $i$-th feature of $x$ and $y$, respectively.
#
# The Euclidean distance is a measure of the distance between two points in Euclidean space. It is the most commonly used distance metric in KNN because it is simple to compute and is effective for a wide variety of datasets.
#
# 3. The distance between each new data point and all the known classified training data points is calculated using the selected distance metric.
#
# 4. The 'k' nearest neighbors, representing the most similar data points from the training set, are identified for each new data point.
#
# 5. The algorithm tallies the number of times each class appears among the 'k' nearest neighbors for each new data point.
#
# 6. The class that has the highest frequency or appears the most frequently among the 'k' nearest neighbors is assigned to the corresponding new data point.

# %% [markdown]
# #### Dataset information

# %% [markdown]
# The iris dataset was introduced by British statistician and biologist Ronald Fisher in his 1936. This dataset comprises 50 samples for each of three Iris flower varieties: Iris setosa, Iris versicolor, and Iris virginica. Each sample includes four attributes: sepal length, sepal width, petal length, and petal width, all measured in centimeters. (1)

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Download the iris data set 
url = "https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv"
df = pd.read_csv(url)

# %%
df.head(5) #show the first 5 rows of df
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.shape #show the shpae fo the dataframe
# Out:
# (150, 5)

# %%
df.info() #Show the information about the datframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum() #Check any null value present
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.describe() #describe the dataset
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Sepal length ranges from 4.3 cm to 7.9 cm with a mean of 5.8 cm and standard deviation 0.82. Sepal width ranges from 2 cm to 4.4 cm with a mean of 3.06 cm and standard deviation 0.43. Petal length ranges from 1.0 cm to 6.9 cm with a mean 3.75 cm and standard deviation 1.76. Petal width ranges from 0.1 cm to 2.5 cm with a mean 1.19 cm and standard deviation 0.76.

# %%
df['variety'].value_counts() #Number of samples in each species
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting data

# %% [markdown]
# #### Histograms

# %%
x = df["sepal.length"]
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
plt.show()

# %%
x = df["sepal.width"]
plt.hist(x, bins = 20, color = "Blue")
plt.title("Sepal Width in cm")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Count")
plt.show()

# %%
x = df["petal.length"]
plt.hist(x, bins = 20, color = "cyan")
plt.title("Petal Length in cm")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.show()

# %%
x = df["petal.width"]
plt.hist(x, bins = 20, color = "red")
plt.title("Petal Width in cm")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Count")
plt.show()

# %%
#Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Pair plot to explore the pair wise relationship between different variables 
g = sns.pairplot(df, hue = 'variety', diag_kind="hist", corner=True)

# %% [markdown]
# It can be observed from the pair plot that the Sestosa species can be easily identified and linearly seperable but Versicolor & Virginica are overlapping and hard to be linearly seperable.

# %% [markdown]
# #### Boxplot

# %%
num_cols = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

for col in num_cols:
    sns.boxplot(x='variety',y=col,data=df,order=['Virginica','Setosa','Versicolor'],orient='v')
    plt.show()

# %% [markdown]
# #### References

# %% [markdown]
# Alpaydın, E. (2014). Introduction to machine learning. Cambridge, MA: MIT Press.
#
# Berry, M. W., Mohamed, A., & Yap, B. W. (2019). Supervised and unsupervised learning for data science. Springer International Publishing.
#
# IBM: What is machine learning? https://www.ibm.com/topics/machine-learning
#
# Khadka, Nirajan (nd.)  Differences Between Parametric and Nonparametric Algorithms: Which One You Need to Pick https://dataaspirant.com/parametric-and-nonparametric-algorithms/
#
# Sandhu, T. H. (2018). Machine learning and natural language processing—A review. International Journal of Advanced Research in Computer Science, 9(2), 582–584.
#
# Verdhan, Vaibhav (2022). Supervised Learning with Python: Concepts and Practical Implementation. Apress.
#
# Zhang Z. (2016). Introduction to machine learning: k-nearest neighbors. Annals of translational medicine, 4(11), 218. https://doi.org/10.21037/atm.2016.03.37
#
# 1. Iris flower data set https://en.wikipedia.org/wiki/Iris_flower_data_set#:~:text=The%20Iris%20flower%20data%20set,example%20of%20linear%20discriminant%20analysis.
